# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('./data/df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b', c='red', edgecolors='black', figsize=(12,4), s=50)

# %%
df3['a'].plot.hist(bins=10, edgecolor='black')

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=10, edgecolor='black', alpha=0.7)

# %%
df3[['a', 'b']].plot.box()

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.kde(ls='--',lw=3)

# %%
axes = df3.plot.area(figsize=(12,4), cmap='coolwarm')
axes.set_xlim([0, 30])
# Out:
# (0, 30)

# %%
df3.loc[0:30, :].plot.area(alpha=0.4, figsize=(12,4))

# %%
axes = df3.plot.area(figsize=(12,4), cmap='coolwarm')
axes.set_xlim([0, 30])
axes.legend(bbox_to_anchor=(1.1, 0.5), loc='center')
